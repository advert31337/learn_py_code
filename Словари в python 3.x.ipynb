# %% [markdown]
# #### Поговорим про объекты?

# %% [markdown]
# В написании программ на часто придется иметь дело с объектами и информацией о нем. Какая информация нас интересует при выборе ноутбука?

# %% [markdown]
# <img src="https://rich-hous.ru/i/imgs/cdn1.ozone.ru/multimedia/1025286751.jpg" alt="alt text" width="500"/>

# %%
notebook = ['процессор', 'видеокарта', 'оперативка', 'жесткий диск']
# Попробуем вписать более подробную информацию
notebook = [['процессор', 'intel', 2300], 'видеокарта', 'оперативка', 'жесткий диск']
# Представим себе что таких ноутбуков много и о каждом надо держать такую информацию
# Удобно работать с такой информацией?

# %%
# Допустим нам надо извлечь частоту процессора, так вроде можно
print(notebook[0][2])
# А представьте себе ситуацию когда сменился программист в компании и вам показали такой код!
# Out:
# 2300

# %%
# А так будет удобнее?
notebook_dict = {'процессор':{'Модель': 'Intel core i5','Кол-во ядер': 4, 'Частота': 2300},
                 'видеокарта': {'Модель': 'Nvidia 2020','Память': '2064'},
                 'Оперативная память': 8,
                 'Беспроводные интерфейсы':['wifi', 'bluetooth']}
print(notebook_dict['процессор']['Частота'])
# Out:
# 2300

# %% [markdown]
# <img src="https://a.d-cd.net/2bef5b6s-1920.jpg" alt="alt text" width="800"/>

# %%
# Для начала повторим списки, условные конструкции и циклы

car_chars = [('Макс. скорость, км/ч', 305),
            ('Разгон, сек.', 4.31),
            ('Мощность, л.с.', 430),
            ('Масса, кг', 1430),
            ('Крутящий момент, об/мин', 544),
            ('Трансмиссия', 'RWD'),
            ('Шины', 'Гоночные')]

car_char = 'Разгон, сек.'
for d in car_chars:
    if car_char in d:
        print(d[1])
        break
else: # если break не случилось, то выполняется else
    print('Не найдено')
# Out:
# 4.31

# %%
print(car_chars[1][1])
# Out:
# 4.31

# %% [markdown]
# ### **СЛОВАРИ (dict)**

# %% [markdown]
# **Словарь (dict) представляет собой неупорядоченную коллекцию произвольных объектов в виде пары ключ:значение**.
# Используются в основном для хранения данных об объекте.
#
# В других языках программирования также встречаются названия ассоциативный массив, хэш-таблица или просто таблица.
# Словарь заключается в фигурные скобки { } каждая запись отделяется запятой, ключ и соответствующее ему значение записывается через двоеточие ":". Общий вид словаря:
# >{key1: value1, key2: value2, ...}
#
# Скорость работы словаря **очень высокая**! Поиск даже в словарях с миллионами записей происходит очень быстро.

# %% [markdown]
# По сути связка "ключ-значение", при этом ключом может быть любой **неизменяемый** объект, например текст, число или кортеж. Изменяемые типы объектов не могут являться ключом, например список.
# При попытке создать изменяемый ключ будет выдаваться ошибка.

# %% [markdown]
# #### создание словарей

# %%
# явное указание элементов словаря
d0 = {'Макс. скорость, км/ч': 305,
      'Разгон, сек.': 4.31,
      'Шины': 'Гоночные'}
# из списка кортежей
list_car_chars = [('Макс. скорость, км/ч', 305),('Разгон, сек.', 4.31),('Мощность, л.с.', 430)]
d1 = dict(list_car_chars)

print(d0)
print(d1)
# Out:
# {'Макс. скорость, км/ч': 305, 'Разгон, сек.': 4.31, 'Шины': 'Гоночные'}
# {'Макс. скорость, км/ч': 305, 'Разгон, сек.': 4.31, 'Мощность, л.с.': 430}

# %%
# другой вариант явного указания элементов (почти не используется)
d2 = dict(Москва=495, СПб=812, Ейск=86132)
print(d2)
# Out:
# {'Москва': 495, 'СПб': 812, 'Ейск': 86132}

# %%
# пустые словари 
dic = {}
dic0 = dict()

print(dic)
print(dic0)
# Out:
# {}
# {}

# %%
# создадим словари со значением None или заданным одинаковым значением по умолчанию
d3 = dict.fromkeys(['a', 'b', 'c'])
d4 = dict.fromkeys(['a', 'b', 'c'], 100)
print(d3)
print(d4)
print('-'*100)
# генератор словарей
d5 = {a: a ** 2 for a in range(7)}
print(d5)
# Out:
# {'a': None, 'b': None, 'c': None}
# {'a': 100, 'b': 100, 'c': 100}
# ----------------------------------------------------------------------------------------------------
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36}

# %% [markdown]
# Ключи словаря содержат только уникальные значения словаря попробуем создать 2 одинаковых ключа

# %%
dict1 = {'a': 1, 'a': 99}
print(dict1, '<- мы попытались 2 раза создать один и тот же ключ')
# Out:
# {'a': 99} <- мы попытались 2 раза создать один и тот же ключ

# %% [markdown]
# #### типы данных в словарях
# В ключах словарей допустимо использовать только неизменяемые типы данных: int, string, tuple.
# В остальных случаях будет вылетать ошибка.

# %%
# присвоим ключу словаря хэшируемый тип - кортеж
key = (1,2)
dict1 = {key: 'дерево'}
print(key,':', dict1[key])
      
# присвоим ключу словаря НЕхэшируемый тип - список
print('\nОшибочка вышла:')
key = [1,2]
dict1 = {key: 'дерево'}
# Out:
# (1, 2) : дерево
#
# Ошибочка вышла:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-0ba80f212fec> in <module>
#       7 print('\nОшибочка вышла:')
#       8 key = [1,2]
# ----> 9 dict1 = {key: 'дерево'}
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# #### Обращаемся к элементам словаря
# Обращаться к записям словаря можно только по ключу, т.к. коллекция неупорядоченная у него просто нет индекса.
# Неупорядоченность значит, что каждый раз вызывая элемент он может находится в разных местах словаря.
# Поэтому словари нельзя сортировать.

# %% [markdown]
# Для примера возьмем кофе-машину, в нем заданный набор ключей в ответ на указанным напиток на экране, возвращает нам чашку с выбранным нами напитком.
# <img src="http://static.pleer.ru/review_photo/356/136/452a68a.jpg" alt="alt text" width="500"/>

# %%
dictionary = {'Макс. скорость, км/ч': 305,
      'Разгон, сек.': 4.31,
      'Шины': 'Гоночные'}
# Получение занчения
print(dictionary.get('Макс. скорость, км/ч'))
print(dictionary['Макс. скорость, км/ч'])
# Out:
# 305
# 305

# %% [markdown]
# При попытке обратиться к несуществующему ключу будет получаем KeyError .

# %%
# ошибка при попытке вызвать несуществующий ключ
dictionary = {'Макс. скорость, км/ч': 305,
      'Разгон, сек.': 4.31,
      'Шины': 'Гоночные'}
print(dict1['Цвет'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-a6d7d0313671> in <module>
#       3       'Разгон, сек.': 4.31,
#       4       'Шины': 'Гоночные'}
# ----> 5 print(dict1['Цвет'])
#
# KeyError: 'Цвет'

# %%
# Для того чтобы избежать ошибки делаем так
print(dictionary.get('Цвет', 'а вот нету тут ничего!'))
# Out:
# а вот нету тут ничего!

# %% [markdown]
# #### добавление/изменение  элемента словаря
# Чтобы добавить в словарь новое значение достаточно после названия словаря в квадратных скобках указать ключ и приравнять его к нужному значению. Точно также можно изменить существующий ключ.
# >dict[key] = value
#
# Или использовать функцию update()
# >dict.update()

# %%
d = {'Макс. скорость, км/ч': 305,
      'Разгон, сек.': 4.31,
      'Шины': 'Гоночные'}
print('До', d)
# Добавление/изменение элементов
d['Цвет'] = 'Черный'
d.update({'Фары': 'Диодные'})
print('После', d)
# Out:
# До {'Макс. скорость, км/ч': 305, 'Разгон, сек.': 4.31, 'Шины': 'Гоночные'}
# После {'Макс. скорость, км/ч': 305, 'Разгон, сек.': 4.31, 'Шины': 'Гоночные', 'Цвет': 'Черный', 'Фары': 'Диодные'}

# %%
# добавляем элемент в словарь и со значением по умолчанию
d.setdefault('Уровень топлива', 0)
print('1', d)
# заправим
d.update({'Уровень топлива': 3})
print('2', d)
# дозаправим еще чуть-чуть
d['Уровень топлива'] +=2
print('3', d)
# Out:
# 1 {'Макс. скорость, км/ч': 305, 'Разгон, сек.': 4.31, 'Шины': 'Гоночные', 'Цвет': 'Черный', 'Фары': 'Диодные', 'Уровень топлива': 0}
# 2 {'Макс. скорость, км/ч': 305, 'Разгон, сек.': 4.31, 'Шины': 'Гоночные', 'Цвет': 'Черный', 'Фары': 'Диодные', 'Уровень топлива': 3}
# 3 {'Макс. скорость, км/ч': 305, 'Разгон, сек.': 4.31, 'Шины': 'Гоночные', 'Цвет': 'Черный', 'Фары': 'Диодные', 'Уровень топлива': 5}

# %% [markdown]
# #### удаление элементов словаря

# %%
d = {'Макс. скорость, км/ч': 305,
      'Разгон, сек.': 4.31,
      'Шины': 'Гоночные',
      'Багажник': 'Есть',
      'Мощность, л.с.': 430,
      'Масса, кг': 1430,
      'Крутящий момент, об/мин': 544,
      'Трансмиссия': 'RWD',
      'Содержимое багажника': ['знак','инстременты', 'насос', 'домкрат']
    }
print(d)
# удаление элемента словаря
del d['Багажник']
print(d)
# возвращает значение и удаляет соответствующий элемент из словаря
print(d.pop('Шины'))
print(d)

# возвращает случайную пару ключ:значение и удаляет его из словаря
print(d.popitem())
print(d)

# удаление всех элементов словаря
d.clear()
print(d)
# Out:
# {'Макс. скорость, км/ч': 305, 'Разгон, сек.': 4.31, 'Шины': 'Гоночные', 'Багажник': 'Есть', 'Мощность, л.с.': 430, 'Масса, кг': 1430, 'Крутящий момент, об/мин': 544, 'Трансмиссия': 'RWD', 'Содержимое багажника': ['знак', 'инстременты', 'насос', 'домкрат']}
# {'Макс. скорость, км/ч': 305, 'Разгон, сек.': 4.31, 'Шины': 'Гоночные', 'Мощность, л.с.': 430, 'Масса, кг': 1430, 'Крутящий момент, об/мин': 544, 'Трансмиссия': 'RWD', 'Содержимое багажника': ['знак', 'инстременты', 'насос', 'домкрат']}
# Гоночные
# {'Макс. скорость, км/ч': 305, 'Разгон, сек.': 4.31, 'Мощность, л.с.': 430, 'Масса, кг': 1430, 'Крутящий момент, об/мин': 544, 'Трансмиссия': 'RWD', 'Содержимое багажника': ['знак', 'инстременты', 'насос', 'домкрат']}
# ('Содержимое багажника', ['знак', 'инстременты', 'насос', 'домкрат'])
# {'Макс. скорость, км/ч': 305, 'Разгон, сек.': 4.31, 'Мощность, л.с.': 430, 'Масса, кг': 1430, 'Крутящий момент, об/мин': 544, 'Трансмиссия': 'RWD'}
# {}

# %% [markdown]
# Проверить наличие ключа в словаре можно при помощи инструкции
# >x in dict

# %%
d = {'Макс. скорость, км/ч': 305,
      'Разгон, сек.': 4.31,
      'Шины': 'Гоночные',
      'Багажник': 'Есть',
      'Мощность, л.с.': 430,
      'Масса, кг': 1430,
      'Крутящий момент, об/мин': 544,
      'Трансмиссия': 'RWD',
    }
print('Багажник' in d, '<- проверка нахождения в словаре элмента a')
print('Масса, кг' in d, '<- проверка нахождения в словаре элмента b')
print('Нитро' in d, '<- проверка нахождения в словаре элмента aa')
# Out:
# True <- проверка нахождения в словаре элмента a
# True <- проверка нахождения в словаре элмента b
# False <- проверка нахождения в словаре элмента aa

# %% [markdown]
# #### перебор элементов словаря

# %% [markdown]
# Можно также возвращать элементы словаря: значения, ключи или связки ключ-значение. Посмотрим код.

# %%
dic = {'Макс. скорость, км/ч': 305,
      'Разгон, сек.': 4.31,
      'Шины': 'Гоночные',
      'Багажник': 'Есть',
      'Мощность, л.с.': 430,
      'Масса, кг': 1430,
      'Крутящий момент, об/мин': 544,
      'Трансмиссия': 'RWD',
    }
print(dic.items())
print('-'*50)
print(dic.keys())
print('-'*50)
print(dic.values())
# Out:
# dict_items([('Макс. скорость, км/ч', 305), ('Разгон, сек.', 4.31), ('Шины', 'Гоночные'), ('Багажник', 'Есть'), ('Мощность, л.с.', 430), ('Масса, кг', 1430), ('Крутящий момент, об/мин', 544), ('Трансмиссия', 'RWD')])
# --------------------------------------------------
# dict_keys(['Макс. скорость, км/ч', 'Разгон, сек.', 'Шины', 'Багажник', 'Мощность, л.с.', 'Масса, кг', 'Крутящий момент, об/мин', 'Трансмиссия'])
# --------------------------------------------------
# dict_values([305, 4.31, 'Гоночные', 'Есть', 430, 1430, 544, 'RWD'])

# %%
for key in dic:
    print(key, dic[key])
# Out:
# Макс. скорость, км/ч 305
# Разгон, сек. 4.31
# Шины Гоночные
# Багажник Есть
# Мощность, л.с. 430
# Масса, кг 1430
# Крутящий момент, об/мин 544
# Трансмиссия RWD

# %%
for key, value in dic.items():
    print(key, value)
# Out:
# Макс. скорость, км/ч 305
# Разгон, сек. 4.31
# Шины Гоночные
# Багажник Есть
# Мощность, л.с. 430
# Масса, кг 1430
# Крутящий момент, об/мин 544
# Трансмиссия RWD

# %%
for key in dic.keys():
    print(key)
# Out:
# Макс. скорость, км/ч
# Разгон, сек.
# Шины
# Багажник
# Мощность, л.с.
# Масса, кг
# Крутящий момент, об/мин
# Трансмиссия

# %%
for value in dic.values():
    print(value)
# Out:
# 305
# 4.31
# Гоночные
# Есть
# 430
# 1430
# 544
# RWD

# %% [markdown]
# #### копирование словаря

# %%
dic = {'Макс. скорость, км/ч': 305,
      'Разгон, сек.': 4.31,
      'Шины': 'Гоночные',
      'Багажник': 'Есть',
      'Мощность, л.с.': 430,
      'Масса, кг': 1430,
      'Крутящий момент, об/мин': 544,
      'Трансмиссия': 'RWD',
      'Содержимое багажника': ['знак','инстременты', 'насос', 'домкрат']}

# %%
ddd = dic
ddd['Масса, кг'] = 2500
print(dic)
# Out:
# {'Макс. скорость, км/ч': 305, 'Разгон, сек.': 4.31, 'Шины': 'Гоночные', 'Багажник': 'Есть', 'Мощность, л.с.': 430, 'Масса, кг': 2500, 'Крутящий момент, об/мин': 544, 'Трансмиссия': 'RWD'}

# %%
co = dic.copy()
co['Масса, кг'] = 1
print(dic)
print('---'*40)
print(co)
# Out:
# {'Макс. скорость, км/ч': 305, 'Разгон, сек.': 4.31, 'Шины': 'Гоночные', 'Багажник': 'Есть', 'Мощность, л.с.': 430, 'Масса, кг': 2500, 'Крутящий момент, об/мин': 544, 'Трансмиссия': 'RWD'}
# ------------------------------------------------------------------------------------------------------------------------
# {'Макс. скорость, км/ч': 305, 'Разгон, сек.': 4.31, 'Шины': 'Гоночные', 'Багажник': 'Есть', 'Мощность, л.с.': 430, 'Масса, кг': 1, 'Крутящий момент, об/мин': 544, 'Трансмиссия': 'RWD'}

# %%
cop = dic.copy()
cop['Содержимое багажника'][0] = 'канистра'
print(dic)
print('---'*40)
print(cop)
# Out:
# {'Макс. скорость, км/ч': 305, 'Разгон, сек.': 4.31, 'Шины': 'Гоночные', 'Багажник': 'Есть', 'Мощность, л.с.': 430, 'Масса, кг': 1430, 'Крутящий момент, об/мин': 544, 'Трансмиссия': 'RWD', 'Содержимое багажника': ['канистра', 'инстременты', 'насос', 'домкрат']}
# ------------------------------------------------------------------------------------------------------------------------
# {'Макс. скорость, км/ч': 305, 'Разгон, сек.': 4.31, 'Шины': 'Гоночные', 'Багажник': 'Есть', 'Мощность, л.с.': 430, 'Масса, кг': 1430, 'Крутящий момент, об/мин': 544, 'Трансмиссия': 'RWD', 'Содержимое багажника': ['канистра', 'инстременты', 'насос', 'домкрат']}

# %%
import copy 


cop = copy.deepcopy(dic)
cop['Содержимое багажника'][0] = 'палатка'
print(dic)
print('---'*40)
print(cop)
# Out:
# {'Макс. скорость, км/ч': 305, 'Разгон, сек.': 4.31, 'Шины': 'Гоночные', 'Багажник': 'Есть', 'Мощность, л.с.': 430, 'Масса, кг': 2500, 'Крутящий момент, об/мин': 544, 'Трансмиссия': 'RWD', 'Содержимое багажника': ['канистра', 'инстременты', 'насос', 'домкрат']}
# ------------------------------------------------------------------------------------------------------------------------
# {'Макс. скорость, км/ч': 305, 'Разгон, сек.': 4.31, 'Шины': 'Гоночные', 'Багажник': 'Есть', 'Мощность, л.с.': 430, 'Масса, кг': 2500, 'Крутящий момент, об/мин': 544, 'Трансмиссия': 'RWD', 'Содержимое багажника': ['палатка', 'инстременты', 'насос', 'домкрат']}

# %% [markdown]
# Словари часто используют для подсчета частоты элементов списков, в этом случае каждый раз нужно производить проверку наличия ключа в словаре. Давайте посмотрим на примере как это можно сделать стандартным способом и применив метод **setdefault()**. Код станет немного короче.

# %%
# список для подсчета элементов
list1 = ['a', 'b', 'a', 'c', 'c','c', 'd', 'b', 'r']

# создадим пустой словарь и циклом подсчитаем количество каждого элемента
dict1 = {}
for el in list1:
    if not el in dict1:
        dict1[el] = 0
    dict1[el] += 1
print(dict1, '<- словарь полученный через проверку in')
      
# то же самое, но методом setdefault()
dict2 = {}
for el in list1:
    dict2.setdefault(el, 0)
    dict2[el] += 1
print(dict2, '<- словарь полученный через метод setdefaul')
# Out:
# {'a': 2, 'b': 2, 'c': 3, 'd': 1, 'r': 1} <- словарь полученный через проверку in
# {'a': 2, 'b': 2, 'c': 3, 'd': 1, 'r': 1} <- словарь полученный через метод setdefaul

# %%
s = 'Когда полезно использовать (*№;№%;%:?(№"№? словарь'
d = {}
for l in sorted(s.lower()):
    if l.isalpha():
        d[l] = d.get(l, 0) + 1
        # if l in d:
        #     d[l] += 1
        # else:
        #     d[l] = 1
print(d)
# Out:
# {'а': 3, 'в': 2, 'г': 1, 'д': 1, 'е': 1, 'з': 2, 'и': 1, 'к': 1, 'л': 3, 'н': 1, 'о': 6, 'п': 2, 'р': 1, 'с': 2, 'т': 1, 'ь': 3}

# %% [markdown]
# Используя функции из стандартной библиотеки **collections** можно расширить функционал.
# Рассмотрим функции **defaultdict** и **Counter**.
# Импортируются функции следующей конструкцией:
# >from collections import defaultdict, Counter

# %%
# создадим словарь содержащий фамилии с установленными значениями по умолчанию
from collections import defaultdict

list1 = ['Иванов', 'Петров', 'Сидоров', 'Кукушкин']

names = defaultdict(int)
for name in list1:
    names[name]
    
names2 = defaultdict(list)
for name in list1:
    names2[name]
    
print(dict(names), '<- словарь с типом данных по умолчанию - число')
print(dict(names2), '<- словарь с типом данных по умолчанию - список')
# Out:
# {'Иванов': 0, 'Петров': 0, 'Сидоров': 0, 'Кукушкин': 0} <- словарь с типом данных по умолчанию - число
# {'Иванов': [], 'Петров': [], 'Сидоров': [], 'Кукушкин': []} <- словарь с типом данных по умолчанию - список

# %%
# функция Counter
from collections import Counter

list1 = ['a', 'b', 'a', 'c', 'c','c', 'd', 'b', 'a', 'a', 'd', 'n']
cnt = Counter(list1)
print(dict(cnt), '<- подсчет количества букв в списке методом Counter')

# выведем самые частые элементы через Counter.most_common()
print(cnt.most_common(3), '<- 3 самых частых элемента через Counter.most_common()')
# Out:
# {'a': 4, 'b': 2, 'c': 3, 'd': 2, 'n': 1} <- подсчет количества букв в списке методом Counter
# [('a', 4), ('c', 3), ('b', 2)] <- 3 самых частых элемента через Counter.most_common()

# %% [markdown]
# Посмотреть список методов и атрибутов словаря можно через функцию dir().

# %%
print(dir({'a': 4}))
# Out:
# ['__class__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']
